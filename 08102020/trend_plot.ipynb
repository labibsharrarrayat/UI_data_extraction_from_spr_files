# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np

# %%
pass_df = pd.read_excel('08102020.xlsx')

# %%
pass_df
# Out:
#          Date      Time  Shot Number StartUp On  Cycl Time (s)  DLck HlpU (%)  \
# 0    08/10/20  19:27:26      1051417  "Start2 "           40.5             91
# 1    08/10/20  19:27:52      1051418  "Start2 "           27.4             91
# 2    08/10/20  19:28:20      1051419  "Start2 "           27.2             91
# 3    08/10/20  19:28:48      1051420  "Start2 "           27.0             91
# 4    08/10/20  19:29:16      1051421  "Start2 "           27.3             92
# 5    08/10/20  19:29:42      1051422  "Start1 "           27.1             91
# 6    08/10/20  19:30:08      1051423  "Start1 "           27.3             92
# 7    08/10/20  19:30:36      1051424  "Start1 "           27.3             91
# 8    08/10/20  19:31:04      1051425  "Start1 "           27.4             92
# 9    08/10/20  19:31:30      1051426  "Start1 "           27.3             92
# 10   08/10/20  19:31:58      1051427  "       "           27.3             92
# ...

# %%
#Set1
fig = plt.figure(figsize=(50,20))

axis1 = fig.add_subplot(3,3,1)
axis1.plot(pass_df['Shot Number'], pass_df['Cycl Time (s)'],color='b')
plt.xlabel('Shot Numbers')
plt.ylabel('Cycl Time (s)')

axis2 = fig.add_subplot(3,3,2)
axis2.plot(pass_df['Shot Number'],pass_df['DLck HlpU (%)'],color='g')
plt.xlabel('Shot Numbers')
plt.ylabel('DLck HlpU (%)')

axis3 = fig.add_subplot(3,3,3)
axis3.plot(pass_df['Shot Number'],pass_df['Low Spd (m/s)'],color='r')
plt.xlabel('Shot Numbers')
plt.ylabel('Low Spd (m/s)')

axis4 = fig.add_subplot(3,3,4)
axis4.plot(pass_df['Shot Number'],pass_df['High Spd (m/s)'],color='tab:purple')
plt.xlabel('Shot Numbers')
plt.ylabel('High Spd (m/s)')

axis5 = fig.add_subplot(3,3,5)
axis5.plot(pass_df['Shot Number'],pass_df['Pres Up T (m/s)'],color='maroon')
plt.xlabel('Shot Numbers')
plt.ylabel('Pres Up T (m/s)')

axis6 = fig.add_subplot(3,3,6)
axis6.plot(pass_df['Shot Number'],pass_df['Cast Pres (MPa)'],color='indigo')
plt.xlabel('Shot Numbers')
plt.ylabel('Cast Pres (MPa)')


axis7 = fig.add_subplot(3,3,7)
axis7.plot(pass_df['Shot Number'],pass_df['Bis Size (mm)'],color='lime')
plt.xlabel('Shot Numbers')
plt.ylabel('Bis Size (mm)')

axis8 = fig.add_subplot(3,3,8)
axis8.plot(pass_df['Shot Number'],pass_df['H-Spd St (mm)'],color='tab:orange')
plt.xlabel('Shot Number')
plt.ylabel('H-Spd St (mm)')

axis9 = fig.add_subplot(3,3,9)
axis9.plot(pass_df['Shot Number'],pass_df['H-Length (mm)'],color='crimson')
plt.xlabel('Shot Numbers')
plt.ylabel('H-Length (mm)')

fig.savefig("trends1.png")
plt.show()

# %%
#Set2
fig = plt.figure(figsize=(50,20))

axis1 = fig.add_subplot(3,3,1)
axis1.plot(pass_df['Shot Number'], pass_df['Fill End (mm)'],color='b')
plt.xlabel('Shot Numbers')
plt.ylabel('Fill End (mm)')

axis2 = fig.add_subplot(3,3,2)
axis2.plot(pass_df['Shot Number'],pass_df['Peek Spd (m/s)'],color='g')
plt.xlabel('Shot Numbers')
plt.ylabel('Peek Spd (m/s)')

axis3 = fig.add_subplot(3,3,3)
axis3.plot(pass_df['Shot Number'],pass_df['Shot Wt (kg)'],color='r')
plt.xlabel('Shot Numbers')
plt.ylabel('Shot Wt (kg)')

axis4 = fig.add_subplot(3,3,4)
axis4.plot(pass_df['Shot Number'],pass_df['Spray (sec)'],color='tab:purple')
plt.xlabel('Shot Numbers')
plt.ylabel('Spray (sec)')

axis5 = fig.add_subplot(3,3,5)
axis5.plot(pass_df['Shot Number'],pass_df['Core In (sec)'],color='maroon')
plt.xlabel('Shot Numbers')
plt.ylabel('Core In (sec)')

axis6 = fig.add_subplot(3,3,6)
axis6.plot(pass_df['Shot Number'],pass_df['DieC lose (sec)'],color='indigo')
plt.xlabel('Shot Numbers')
plt.ylabel('DieC lose (sec)')


axis7 = fig.add_subplot(3,3,7)
axis7.plot(pass_df['Shot Number'],pass_df['Pouring (sec)'],color='lime')
plt.xlabel('Shot Numbers')
plt.ylabel('Pouring (sec)')

axis8 = fig.add_subplot(3,3,8)
axis8.plot(pass_df['Shot Number'],pass_df['Fill Pres (MPa)'],color='tab:orange')
plt.xlabel('Shot Number')
plt.ylabel('Fill Pres (MPa)')

axis9 = fig.add_subplot(3,3,9)
axis9.plot(pass_df['Shot Number'],pass_df['Fill Time (ms)'],color='crimson')
plt.xlabel('Shot Numbers')
plt.ylabel('Fill Time (ms)')

fig.savefig("trends2.png")
plt.show()

# %%
#Set3
fig = plt.figure(figsize=(50,20))

axis1 = fig.add_subplot(3,3,1)
axis1.plot(pass_df['Shot Number'], pass_df['Work Cool (sec)'],color='b')
plt.xlabel('Shot Numbers')
plt.ylabel('Work Cool (sec)')

axis2 = fig.add_subplot(3,3,2)
axis2.plot(pass_df['Shot Number'],pass_df['Die Open (sec)'],color='g')
plt.xlabel('Shot Numbers')
plt.ylabel('Die Open (sec)')

axis3 = fig.add_subplot(3,3,3)
axis3.plot(pass_df['Shot Number'],pass_df['D-Height (mm)'],color='r')
plt.xlabel('Shot Numbers')
plt.ylabel('D-Height (mm)')

axis4 = fig.add_subplot(3,3,4)
axis4.plot(pass_df['Shot Number'],pass_df['Pour Ret (deg)'],color='tab:purple')
plt.xlabel('Shot Numbers')
plt.ylabel('Pour Ret (deg)')

axis5 = fig.add_subplot(3,3,5)
axis5.plot(pass_df['Shot Number'],pass_df['A M.Temp 1 Max (ßC)'],color='maroon')
plt.xlabel('Shot Numbers')
plt.ylabel('A M.Temp 1 Max (ßC)')

axis6 = fig.add_subplot(3,3,6)
axis6.plot(pass_df['Shot Number'],pass_df['A M.Temp 1 Min (ßC)'],color='indigo')
plt.xlabel('Shot Numbers')
plt.ylabel('A M.Temp 1 Min (ßC)')


axis7 = fig.add_subplot(3,3,7)
axis7.plot(pass_df['Shot Number'],pass_df['B M.Temp 2 Max (ßC)'],color='lime')
plt.xlabel('Shot Numbers')
plt.ylabel('B M.Temp 2 Max (ßC)')

axis8 = fig.add_subplot(3,3,8)
axis8.plot(pass_df['Shot Number'],pass_df['B M.Temp 2 Min (ßC)'],color='tab:orange')
plt.xlabel('Shot Number')
plt.ylabel('B M.Temp 2 Min (ßC)')

axis9 = fig.add_subplot(3,3,9)
axis9.plot(pass_df['Shot Number'],pass_df['Inten Tms'],color='crimson')
plt.xlabel('Shot Numbers')
plt.ylabel('Inten Tms')

fig.savefig("trends3.png")
plt.show()

# %%
#Set4
fig = plt.figure(figsize=(50,20))

axis1 = fig.add_subplot(3,3,1)
axis1.plot(pass_df['Shot Number'], pass_df['C F.Temp 1 Max (ßC)'],color='b')
plt.xlabel('Shot Numbers')
plt.ylabel('C F.Temp 1 Max (ßC)')

axis2 = fig.add_subplot(3,3,2)
axis2.plot(pass_df['Shot Number'],pass_df['C F.Temp 1 Min (ßC)'],color='g')
plt.xlabel('Shot Numbers')
plt.ylabel('C F.Temp 1 Min (ßC)')

axis3 = fig.add_subplot(3,3,3)
axis3.plot(pass_df['Shot Number'],pass_df['Fill Stat (mm)'],color='r')
plt.xlabel('Shot Numbers')
plt.ylabel('Fill Stat (mm)')

axis4 = fig.add_subplot(3,3,4)
axis4.plot(pass_df['Shot Number'],pass_df['P Up Stat (mm)'],color='tab:purple')
plt.xlabel('Shot Numbers')
plt.ylabel('P Up Stat (mm)')

axis5 = fig.add_subplot(3,3,5)
axis5.plot(pass_df['Shot Number'],pass_df['Core Out (sec)'],color='maroon')
plt.xlabel('Shot Numbers')
plt.ylabel('Core Out (sec)')

axis6 = fig.add_subplot(3,3,6)
axis6.plot(pass_df['Shot Number'],pass_df['Eject (sec)'],color='indigo')
plt.xlabel('Shot Numbers')
plt.ylabel('Eject (sec)')


axis7 = fig.add_subplot(3,3,7)
axis7.plot(pass_df['Shot Number'],pass_df['Take-Out (sec)'],color='lime')
plt.xlabel('Shot Numbers')
plt.ylabel('Take-Out (sec)')

axis8 = fig.add_subplot(3,3,8)
axis8.plot(pass_df['Shot Number'],pass_df['D F.Temp 2 Max (ßC)'],color='tab:orange')
plt.xlabel('Shot Number')
plt.ylabel('D F.Temp 2 Max (ßC)')

axis9 = fig.add_subplot(3,3,9)
axis9.plot(pass_df['Shot Number'],pass_df['Shtpres (MPa)'],color='crimson')
plt.xlabel('Shot Numbers')
plt.ylabel('Shtpres (MPa)')

fig.savefig("trends4.png")
plt.show()

# %%
#Set5
fig = plt.figure(figsize=(50,20))

axis1 = fig.add_subplot(3,3,1)
axis1.plot(pass_df['Shot Number'], pass_df['D F.Temp 2 Min (ßC)'],color='b')
plt.xlabel('Shot Numbers')
plt.ylabel('D F.Temp 2 Min (ßC)')

axis2 = fig.add_subplot(3,3,2)
axis2.plot(pass_df['Shot Number'],pass_df['C F.Temp 1 Min (ßC)'],color='g')
plt.xlabel('Shot Numbers')
plt.ylabel('C F.Temp 1 Min (ßC)')

axis3 = fig.add_subplot(3,3,3)
axis3.plot(pass_df['Shot Number'],pass_df['E Metal Ave (ßC)'],color='r')
plt.xlabel('Shot Numbers')
plt.ylabel('E Metal Ave (ßC)')

axis4 = fig.add_subplot(3,3,4)
axis4.plot(pass_df['Shot Number'],pass_df['F M.Cool. Ave(ßC)'],color='tab:purple')
plt.xlabel('Shot Numbers')
plt.ylabel('F M.Cool. Ave(ßC)')

axis5 = fig.add_subplot(3,3,5)
axis5.plot(pass_df['Shot Number'],pass_df['M.Cooling Water (l/m)'],color='maroon')
plt.xlabel('Shot Numbers')
plt.ylabel('M.Cooling Water (l/m)')

axis6 = fig.add_subplot(3,3,6)
axis6.plot(pass_df['Shot Number'],pass_df['F.Cooling Water (l/m)'],color='indigo')
plt.xlabel('Shot Numbers')
plt.ylabel('F.Cooling Water (l/m)')


axis7 = fig.add_subplot(3,3,7)
axis7.plot(pass_df['Shot Number'],pass_df['Tip Cooling Flow (l/m)'],color='lime')
plt.xlabel('Shot Numbers')
plt.ylabel('Tip Cooling Flow (l/m)')

axis8 = fig.add_subplot(3,3,8)
axis8.plot(pass_df['Shot Number'],pass_df['Oil Cooler Flow (l/m)'],color='tab:orange')
plt.xlabel('Shot Number')
plt.ylabel('Oil Cooler Flow (l/m)')

axis9 = fig.add_subplot(3,3,9)
axis9.plot(pass_df['Shot Number'],pass_df['VShutPos (mm)'],color='crimson')
plt.xlabel('Shot Numbers')
plt.ylabel('VShutPos (mm)')

fig.savefig("trends5.png")
plt.show()

# %%
#Set6
fig = plt.figure(figsize=(50,20))

axis1 = fig.add_subplot(3,3,1)
axis1.plot(pass_df['Shot Number'], pass_df['DieLub.SprayLe (ml)'],color='b')
plt.xlabel('Shot Numbers')
plt.ylabel('DieLub.SprayLe (ml)')

axis2 = fig.add_subplot(3,3,2)
axis2.plot(pass_df['Shot Number'],pass_df['Vacuum (kPa)'],color='g')
plt.xlabel('Shot Numbers')
plt.ylabel('Vacuum (kPa)')

axis3 = fig.add_subplot(3,3,3)
axis3.plot(pass_df['Shot Number'],pass_df['Peak Vacum (kPa)'],color='r')
plt.xlabel('Shot Numbers')
plt.ylabel('Peak Vacum (kPa)')



fig.savefig("trends6.png")
plt.show()
